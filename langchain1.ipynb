# %%
from dotenv import load_dotenv
import os

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

# %%
load_dotenv()
# Out:
# True

# %%
llm=ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.10
)

# %%
question=input("enter your question")

# %%
response=llm.invoke([HumanMessage(content=question)])

# %%
print(response.content)
# Out:
# **SI** stands for **Système International d'Unités**, which is French for the **International System of Units**.
#
# It is the modern form of the metric system and is the most widely used system of measurement globally, adopted by almost every country in the world for scientific, technical, industrial, and commercial purposes.
#
# Here's a breakdown of what SI is and why it's so important:
#
# 1.  **Purpose:** To provide a coherent, standardized, and universally accepted set of units for all measurements. This ensures that scientists, engineers, traders, and people across different countries can communicate and understand measurements without ambiguity.
#
# 2.  **Key Features:**
#     *   **Coherence:** All units are logically related to each other.
#     *   **Decimal System:** It is based on powers of 10, making conversions between multiples and submultiples of units very straightforward (e.g., 1 kilometer = 1000 meters).
#     *   **Universality:** It's the standard in almost all countries, facilitating international trade, science, and communication.
#     *   **Reproducibility:** The definitions of the base units are precise and can be realized anywhere in the world.
#
# 3.  **The Seven Base Units:** These are the fundamental building blocks of the SI system, from which all other units are derived. As of the 2019 redefinition, all base units are defined in terms of fundamental physical constants.
#     *   **Length:** **meter** (m)
#     *   **Mass:** **kilogram** (kg)
#     *   **Time:** **second** (s)
#     *   **Electric Current:** **ampere** (A)
#     *   **Thermodynamic Temperature:** **kelvin** (K)
#     *   **Amount of Substance:** **mole** (mol)
#     *   **Luminous Intensity:** **candela** (cd)
#
# 4.  **Derived Units:** These units are formed by combining the base units. Many derived units have special names for convenience.
#     *   **Area:** square meter (m²)
#     *   **Volume:** cubic meter (m³)
#     *   **Speed:** meter per second (m/s)
#     *   **Force:** newton (N) (which is kg·m/s²)
#     *   **Energy:** joule (J) (which is N·m)
#     *   **Power:** watt (W) (which is J/s)
#     *   **Pressure:** pascal (Pa) (which is N/m²)
#
# 5.  **SI Prefixes:** These are used to denote multiples and submultiples of the units, making it easy to express very large or very small quantities without using many zeros.
#     *   **kilo-** (k) = 10³ (1000) e.g., kilometer
#     *   **mega-** (M) = 10⁶ (1,000,000) e.g., megawatt
#     *   **giga-** (G) = 10⁹ (1,000,000,000) e.g., gigabyte
#     *   **milli-** (m) = 10⁻³ (0.001) e.g., millimeter
#     *   **micro-** (µ) = 10⁻⁶ (0.000001) e.g., micrometer
#     *   **nano-** (n) = 10⁻⁹ (0.000000001) e.g., nanosecond
#
# **Why is SI important?**
#
# *   **Global Standardization:** It provides a common language for measurement, essential for international collaboration in science, engineering, and commerce.
# *   **Accuracy and Precision:** Its definitions, especially after the 2019 redefinition based on fundamental physical constants, ensure the highest levels of accuracy and reproducibility.
# *   **Simplicity:** The decimal nature and coherent structure make calculations and conversions straightforward, reducing errors.
#
# In essence, SI is the universal language of measurement that underpins almost all modern scientific, technological, and economic activities.
