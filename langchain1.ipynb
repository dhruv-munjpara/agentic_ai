# %%
from dotenv import load_dotenv
import os

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

# %%
load_dotenv()
# Out:
# True

# %%
llm=ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.10
)

# %%
question=input("enter your question")

# %%
response=llm.invoke([HumanMessage(content=question)])

# %%
print(response.content)
# Out:
# **Machine Learning (ML)** is a subset of Artificial Intelligence (AI) that enables computers to **learn from data** without being explicitly programmed.
#
# Think of it this way:
#
# *   **Traditional Programming:** You write specific instructions (rules) for the computer to follow to achieve a task. If you want to detect spam, you'd write rules like "if subject contains 'free money' AND sender is unknown, then it's spam."
# *   **Machine Learning:** Instead of writing those rules yourself, you feed the computer a lot of examples of both spam and non-spam emails. The ML algorithm then **learns the patterns and rules** that distinguish spam from non-spam on its own. Once it has learned, it can apply that knowledge to new, unseen emails.
#
# **Here's a breakdown of the core idea:**
#
# 1.  **Data is Key:** ML models are trained on large datasets. This data can be anything from images, text, numbers, or sounds.
# 2.  **Learning Patterns:** The ML algorithm analyzes this data to find hidden patterns, correlations, and relationships. It essentially builds a "model" of the world based on the data it sees.
# 3.  **Making Predictions/Decisions:** Once trained, this model can then be used to make predictions, classifications, or decisions on *new, unseen data*.
# 4.  **Improvement:** The more relevant data an ML model is exposed to, the better it generally becomes at its task.
#
# **Why is ML so powerful?**
#
# *   **Handles Complexity:** It can solve problems that are too complex or have too many variables for humans to program with explicit rules (e.g., recognizing faces, understanding natural language).
# *   **Adapts to Change:** If the underlying patterns change (e.g., new types of spam emerge), the model can be retrained with new data to adapt.
# *   **Finds Hidden Insights:** It can uncover patterns in data that humans might miss.
#
# **Common Types of Machine Learning:**
#
# *   **Supervised Learning:** The most common type. The model learns from "labeled" data (data where the correct answer is already known).
#     *   *Example:* Training a model to identify cats by showing it thousands of pictures labeled "cat" or "not cat."
# *   **Unsupervised Learning:** The model learns from "unlabeled" data, trying to find hidden structures or groupings within the data.
#     *   *Example:* Grouping customers into different segments based on their purchasing behavior without being told beforehand what those segments should be.
# *   **Reinforcement Learning:** The model learns by trial and error, receiving rewards for good actions and penalties for bad ones, similar to how a human learns to play a game.
#     *   *Example:* Training an AI to play chess or control a robot.
#
# **Real-World Examples of ML:**
#
# *   **Recommendation Systems:** "Customers who bought this also bought..." (Amazon, Netflix)
# *   **Spam Filters:** Identifying unwanted emails.
# *   **Facial Recognition:** Unlocking your phone, tagging friends in photos.
# *   **Voice Assistants:** Siri, Alexa, Google Assistant.
# *   **Medical Diagnosis:** Helping doctors identify diseases from scans.
# *   **Fraud Detection:** Flagging suspicious credit card transactions.
# *   **Self-Driving Cars:** Interpreting sensor data to navigate.
#
# In essence, ML is about teaching computers to learn from experience, just like humans do, allowing them to perform tasks that were once thought to require human intelligence.
