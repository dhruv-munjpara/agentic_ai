# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage,AIMessage

# %%
load_dotenv()
# Out:
# True

# %%
llm=ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

# %%
messages=[]

# %%
question=input("hi:")
messages.append(
    HumanMessage(content=question)
)

response=llm.invoke(messages)

messages.append(
    AIMessage(content=response.content)
)

print("AI:",response.content)
# Out:
# AI: Okay, I can certainly suggest some different names for you! These are just ideas, of course, and you can pick whichever one you like, or none at all.
#
# How about one of these:
#
# *   **Aryan**
# *   **Rohan**
# *   **Kian**
# *   **Samir**
# *   **Arjun**
#
# Do any of those sound interesting, or would you like some more suggestions?
#
# For now, I'll continue to remember you as **Dhruv** unless you tell me you'd like to use one of these new names, or a different one entirely!
